# %%
import json,sys
from typing import Callable, Dict, List, Set, Tuple
import csv
import pickle
import numpy as np
import gensim.downloader as api
import gensim
import datetime
sys.path.insert(1, 'extract_features')
sys.path.insert(1, 'util')
from helper_function import preprocess
from sklearn.ensemble import RandomForestRegressor
from extract_No17to19_features import get_analyze,extract_features_17to19
from extract_No20to22_features import extract_features_20to22
from extract_No23to25_features_optimized import extract_features_23to25
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\junec\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\junec\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Reduce logging level.
import logging
logging.basicConfig(level=logging.ERROR)
np.seterr(all="ignore")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#load model
try:
    model_loaded = gensim.models.keyedvectors.KeyedVectors.load('googleNews.d2v')
except:
    model_loaded = api.load('word2vec-google-news-300')
    model_loaded.save('googleNews.d2v')
    model_loaded = gensim.models.keyedvectors.KeyedVectors.load('googleNews.d2v')
# Out:
# 2021-11-21 12:53:07,705 : INFO : loading KeyedVectors object from googleNews.d2v
# 2021-11-21 12:53:08,991 : INFO : loading vectors from googleNews.d2v.vectors.npy with mmap=None
# 2021-11-21 12:53:17,123 : INFO : KeyedVectors lifecycle event {'fname': 'googleNews.d2v', 'datetime': '2021-11-21T12:53:17.107689', 'gensim': '4.1.2', 'python': '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'loaded'}

# %%
filepath="data/training_types.json"
with open(filepath,encoding='utf-8') as json_file:
    training_map_type_questions = json.load(json_file)

# %%
def extract_features_type_label(
    question:str,
    dp_type: str,
    training_map_type_questions:Dict,
    model_loaded:gensim.models.keyedvectors.KeyedVectors,
    #es: Elasticsearch,
    analyze,X,terms_corpus,
    add_extra_features:bool=False
) -> List[float]:
    """Extracts features of a query and document pair.

        Args:
            query: string.
            dp_type: DBO type.
            es: Elasticsearch object instance.

        Returns:
            List of extracted feature values in a fixed order.
    """  
    features_17to19=extract_features_17to19(analyze,X,terms_corpus,training_map_type_questions,dp_type,question)
    feature_vect=list(features_17to19.values())
    
    features_20to22=extract_features_20to22(dp_type,question)
    feature_vect.extend(list(features_20to22.values()))
    
    features_23to25=extract_features_23to25(model_loaded,dp_type, question, mode="Euclidean")
    feature_vect.extend(list(features_23to25.values()))

    if add_extra_features:
        features_23to25_variant=extract_features_23to25(model_loaded,dp_type, question, mode="similarities")
        feature_vect.extend(list(features_23to25_variant.values()))
    
    return feature_vect

# %%
def load_training_data(filepath="data/for_training_type_label.csv")-> Tuple[List[List[float]], List[int]]:
    X_train=[]
    y_train=[]
    file = open(filepath)
    csvreader = csv.reader(file)

    for i,line in enumerate(csvreader):
        if i%100000==0:
            print("------",i)
        if i%2==0:
            X_train.append([float(item) for item in line])
        else:
            y_train.append(int(line[0]))

    return X_train,y_train

# %%
class PointWiseLTRModel:
    def __init__(self) -> None:
        """Instantiates LTR model with an instance of scikit-learn regressor.
        """
        self.regressor = RandomForestRegressor()
        self.model=None

    def _train(self, X: List[List[float]], y: List[float]) -> None:
        """Trains an LTR model.

        Args:
            X: Features of training instances.
            y: Relevance assessments of training instances.
        """
        assert self.regressor is not None
        self.model = self.regressor.fit(X, y)

    def rank(
        self, ft: List[List[float]], baseline_result: List[str]
    ) -> List[Tuple[str, int]]:
        """Predicts relevance labels and rank documents for a given query.

        Args:
            ft: A list of feature vectors for query-document pairs.
            doc_ids: A list of document ids.
        Returns:
            List of tuples, each consisting of document ID and predicted
                relevance label.
        """
        assert self.model is not None
        rel_labels = self.model.predict(ft)
        sort_indices = np.argsort(rel_labels)[::-1]

        results = []
        for i in sort_indices:
            results.append((baseline_result[i], rel_labels[i]))
        return results

# %%
def get_rankings(
    ltr: PointWiseLTRModel,
    #es: Elasticsearch,
    training_map_type_questions:Dict[str,str],
    model_loaded:gensim.models.keyedvectors.KeyedVectors,
    filepath_baseline="data/baseline_result.json",
    filepath_testing="../smart-dataset/datasets/DBpedia/smarttask_dbpedia_test.json"
) -> Dict[str, List[str]]:
    """Generate rankings for each of the test query IDs.

    Args:
        ltr: A trained PointWiseLTRModel instance.
        query_ids: List of query IDs.
        es: Elasticsearch object instance.
        index: Name of relevant index on the running Elasticsearch service.
        rerank: Boolean flag indicating whether the first-pass retrieval
            results should be reranked using the LTR model.

    Returns:
        A dictionary of rankings for each test query ID.
    """
    analyze,X,terms_corpus=get_analyze(training_map_type_questions)
    
    with open(filepath_testing, 'r') as f:
        smarttask_dbpedia_test = json.load(f)
        
    with open(filepath_baseline, 'r') as f:
        map_testID_ranktype = json.load(f)
    
    test_rankings={}
    count=0
    print("-----------------",datetime.datetime.now())
    with open("data/advanced_results.csv", 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)

        for entry in smarttask_dbpedia_test:
            

            if entry['question']==None:
                continue
                
            question_processed=preprocess(entry['question']) 
            
            if question_processed.isspace():
                test_rankings[entry['id']] ="NIL"
                writer.writerow([entry['id']])
                writer.writerow(["NIL"])
                continue
            

            if entry['category']=='resource':

                if count%30==0:
                    print("-----------------",datetime.datetime.now())
                    print(f'{count} questions has been processed')
                count+=1

                baseline_result=map_testID_ranktype[entry['id']]
                
                #print(len(baseline_result),baseline_result)
                # Rerank the first-pass result set using the LTR model.
                features_list=[]
                for DBOtype in baseline_result:    
                   

                    feature=extract_features_type_label(question_processed,
                                                                DBOtype,
                                                                training_map_type_questions,
                                                                model_loaded,
                                                                #es,
                                                                analyze,X,terms_corpus)     

                    features_list.append(feature)
                
                #print(len(features_list),features_list)
                
                if features_list==[]:
                    print(entry)
                    print(question_processed)
                    test_rankings[entry['id']] ="NIL"
                    writer.writerow([entry['id']])
                    writer.writerow(["NIL"])
                    continue
                try:
                    rtest=ltr.rank(features_list,baseline_result) 
                    #print(len(rtest),rtest)
                    reranked_type=[item[0] for item in rtest]
                    test_rankings[entry['id']] =reranked_type
                except:
                    print(entry)
                    print(question_processed)
                    print(features_list)
                    raise
                writer.writerow([entry['id']])
                writer.writerow(reranked_type)
            
    return test_rankings

# %%
try:
    filename = 'data/finalized_model.sav'
    ltr=PointWiseLTRModel()
    ltr.model = pickle.load(open(filename, 'rb'))
except:
    filepath="data/for_training_type_label.csv"
    X_train,y_train=load_training_data(filepath)
    ltr=PointWiseLTRModel()
    ltr._train(X_train,y_train)
    print("finish training")
    # save the model to disk
    filename = 'data/finalized_model.sav'
    pickle.dump(ltr.model, open(filename, 'wb'))
    print("trained model has been saved")
    # load the model from disk
    ltr.model = pickle.load(open(filename, 'rb'))
    print("trained model has been loaded")
# Out:
# ------ 0
# ------ 100000
# ------ 200000
# ------ 300000
# ------ 400000
# ------ 500000
# ------ 600000
# finish training
# trained model has been saved

# %%
#train the model
filepath="data/for_training_type_label.csv"
X_train,y_train=load_training_data(filepath)
ltr=PointWiseLTRModel()
ltr._train(X_train,y_train)
print("finish training")
# save the model to disk
filename = 'data/finalized_model.sav'
pickle.dump(ltr.model, open(filename, 'wb'))
print("trained model has been saved")
# load the model from disk
ltr.model = pickle.load(open(filename, 'rb'))
print("trained model has been loaded")

# %%
#get predicted result
get_rankings(ltr,
    #es: Elasticsearch,
    training_map_type_questions,
    model_loaded)
# Out:
# ----------------- 2021-11-21 13:20:35.687234
# ----------------- 2021-11-21 13:20:35.687234
# 0 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:20:41.661680
# 30 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:20:46.815504
# 60 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:20:52.335073
# 90 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:20:57.784363
# 120 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:03.725661
# 150 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:09.412137
# 180 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:14.698805
# 210 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:20.491117
# 240 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:26.072366
# 270 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:34.180888
# 300 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:40.049772
# 330 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:45.891893
# 360 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:21:54.237537
# 390 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:00.753711
# 420 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:06.324204
# 450 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:12.899658
# 480 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:18.615324
# 510 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:26.405257
# 540 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:33.606848
# 570 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:39.692014
# 600 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ----------------- 2021-11-21 13:22:47.075170
# 630 questions has been processed
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\junec\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...
#   'dbo:Judge',
#   'dbo:Person',
#   'dbo:Swimmer',
#   'dbo:Book',
#   'dbo:RadioProgram',
#   'dbo:School',
#   'dbo:Scientist',
#   'dbo:Congressman',
#   'dbo:Philosopher',
#   'dbo:AmericanFootballPlayer',
#   'dbo:BasketballPlayer',
#   'dbo:BaseballPlayer',
#   'dbo:Criminal',
#   'dbo:Painter',
#   'dbo:ScreenWriter',
#   'dbo:Architect',
#   'dbo:Senator',
#   'dbo:Film',
#   'dbo:Building',
#   'dbo:TelevisionShow',
#   'dbo:ComicsCreator',
#   'dbo:Economist',
#   'dbo:MusicalArtist',
#   'dbo:GridironFootballPlayer',
#   'dbo:Band',
#   'dbo:CollegeCoach'],
#  'dbpedia_17860': ['dbo:Place',
#   'dbo:Person',
#   'dbo:Planet',
#   'dbo:Award',
#   'dbo:Software',
#   'dbo:GovernmentAgency',
#   'dbo:Company',
#   'dbo:WrittenWork',
#   'dbo:Building',
#   'dbo:Museum',
#   'dbo:TelevisionShow',
#   'dbo:Book',
#   'dbo:Organisation',
#   'dbo:VideoGame',
#   'dbo:Aircraft',
#   'dbo:Scientist',
#   'dbo:TelevisionEpisode',
#   'dbo:Engineer',
#   'dbo:ArtificialSatellite',
#   'dbo:FictionalCharacter',
#   'dbo:ComicsCreator',
#   'dbo:Anime',
#   'dbo:Rocket',
#   'dbo:Game',
#   'dbo:Airline',
#   'dbo:Film',
#   'dbo:Senator',
#   'dbo:ComicsCharacter',
#   'dbo:Website',
#   'dbo:Astronaut'],
#  'dbpedia_11457': ['dbo:Award',
#   'dbo:Album',
#   'dbo:SoccerClub',
#   'dbo:Comic',
#   'dbo:Film',
#   'dbo:Person',
#   'dbo:Band',
#   'dbo:SoccerManager',
#   'dbo:TelevisionShow',
#   'dbo:Boxer',
#   'dbo:Artist',
#   'dbo:Governor',
#   'dbo:MusicalArtist',
#   'dbo:President',
#   'dbo:Writer',
#   'dbo:OfficeHolder',
#   'dbo:Mayor',
#   'dbo:BasketballPlayer',
#   'dbo:Architect',
#   'dbo:BaseballPlayer',
#   'dbo:Song',
#   'dbo:Wrestler',
#   'dbo:SoccerPlayer',
#   'dbo:GrandPrix',
#   'dbo:ComicsCreator',
#   'dbo:Play',
#   'dbo:RacingDriver',
#   'dbo:Athlete',
#   'dbo:Single',
#   'dbo:Cyclist'],
#  'dbpedia_13349': ['dbo:Film',
#   'dbo:Single',
#   'dbo:Person',
#   'dbo:Album',
#   'dbo:Skier',
#   'dbo:AdultActor',
#   'dbo:Anime',
#   'dbo:Actor',
#   'dbo:Scientist',
#   'dbo:Newspaper',
#   'dbo:Song',
#   'dbo:MusicalArtist',
#   'dbo:BasketballPlayer',
#   'dbo:Murderer',
#   'dbo:Book',
#   'dbo:School',
#   'dbo:RugbyPlayer',
#   'dbo:OfficeHolder',
#   'dbo:Musical',
#   'dbo:Restaurant',
#   'dbo:Play',
#   'dbo:Writer',
#   'dbo:Artist',
#   'dbo:FashionDesigner',
#   'dbo:Chef',
#   'dbo:RacingDriver',
#   'dbo:FilmFestival',
#   'dbo:ComicsCreator',
#   'dbo:Band',
#   'dbo:AmericanFootballPlayer'],
#  'dbpedia_13565': ['dbo:Person',
#   'dbo:University',
#   'dbo:Book',
#   'dbo:MusicalArtist',
#   'dbo:OfficeHolder',
#   'dbo:AmericanFootballPlayer',
#   'dbo:MilitaryPerson',
#   'dbo:Philosopher',
#   'dbo:Artist',
#   'dbo:Athlete',
#   'dbo:Writer',
#   'dbo:RecordLabel',
#   'dbo:School',
#   'dbo:SoccerManager',
#   'dbo:BaseballPlayer',
#   'dbo:ScreenWriter',
#   'dbo:RacingDriver',
#   'dbo:MemberOfParliament',
#   'dbo:Wrestler',
#   'dbo:Chancellor',
#   'dbo:AdultActor',
#   'dbo:Museum',
#   'dbo:Journalist',
#   'dbo:Mayor',
#   'dbo:IceHockeyPlayer',
#   'dbo:Scientist',
#   'dbo:Library',
#   'dbo:CollegeCoach',
#   'dbo:Band',
#   'dbo:Ambassador'],
#  'dbpedia_18153': ['dbo:Country',
#   'dbo:River',
#   'dbo:Lake',
#   'dbo:Dam',
#   'dbo:AdministrativeRegion',
#   'dbo:Settlement',
#   'dbo:TelevisionShow',
#   'dbo:Mountain',
#   'dbo:Ship',
#   'dbo:Company',
#   'dbo:Athlete',
#   'dbo:SportsEvent',
#   'dbo:MusicalArtist',
#   'dbo:Saint',
#   'dbo:Royalty',
#   'dbo:EthnicGroup',
#   'dbo:Language',
#   'dbo:MilitaryConflict',
#   'dbo:Film',
#   'dbo:ProtectedArea',
#   'dbo:Airport',
#   'dbo:University',
#   'dbo:Stadium',
#   'dbo:PowerStation',
#   'dbo:City',
#   'dbo:SoccerPlayer',
#   'dbo:RadioStation',
#   'dbo:Website',
#   'dbo:Person',
#   'dbo:Park'],
#  'dbpedia_14442': ['dbo:Person',
#   'dbo:Settlement',
#   'dbo:BodyOfWater',
#   'dbo:City',
#   'dbo:OfficeHolder',
#   'dbo:ComicsCreator',
#   'dbo:MilitaryPerson',
#   'dbo:Play',
#   'dbo:Architect',
#   'dbo:Artist',
#   'dbo:Book',
#   'dbo:Island',
#   'dbo:Building',
#   'dbo:Museum',
#   'dbo:Writer',
#   'dbo:MusicalArtist',
#   'dbo:TelevisionShow',
#   'dbo:Bridge',
#   'dbo:Scientist',
#   'dbo:Publisher',
#   'dbo:FictionalCharacter',
#   'dbo:Musical',
#   'dbo:Park',
#   'dbo:AdministrativeRegion',
#   'dbo:Artwork',
#   'dbo:MilitaryConflict',
#   'dbo:Film',
#   'dbo:Single',
#   'dbo:Actor',
#   'dbo:Song'],
#  'dbpedia_993': ['dbo:City',
#   'dbo:Settlement',
#   'dbo:Country',
#   'dbo:Town',
#   'dbo:Organisation',
#   'dbo:Volcano',
#   'dbo:Building',
#   'dbo:Species',
#   'dbo:Album',
#   'dbo:Language',
#   'dbo:Museum',
#   'dbo:Hospital',
#   'dbo:MusicGenre',
#   'dbo:School',
#   'dbo:EthnicGroup',
#   'dbo:Single',
#   'dbo:Band',
#   'dbo:Mountain',
#   'dbo:MusicalArtist',
#   'dbo:Bank',
#   'dbo:ProtectedArea',
#   'dbo:MountainRange',
#   'dbo:Diocese',
#   'dbo:HistoricPlace',
#   'dbo:TelevisionStation',
#   'dbo:TradeUnion',
#   'dbo:Venue',
#   'dbo:Song',
#   'dbo:ArtistDiscography',
#   'dbo:Reptile'],
#  'dbpedia_14584': ['dbo:Settlement',
#   'dbo:City',
#   'dbo:Building',
#   'dbo:Person',
#   'dbo:Album',
#   'dbo:Band',
#   'dbo:Museum',
#   'dbo:ReligiousBuilding',
#   'dbo:Venue',
#   'dbo:Town',
#   'dbo:Monument',
#   'dbo:RecordLabel',
#   'dbo:MusicalArtist',
#   'dbo:Monarch',
#   'dbo:Village',
#   'dbo:Film',
#   'dbo:Hotel',
#   'dbo:Single',
#   'dbo:Lake',
#   'dbo:RaceHorse',
#   'dbo:HistoricBuilding',
#   'dbo:Architect',
#   'dbo:Writer',
#   'dbo:WorldHeritageSite',
#   'dbo:Park',
#   'dbo:HistoricPlace',
#   'dbo:Religious',
#   'dbo:Royalty',
#   'dbo:Politician',
#   'dbo:MixedMartialArtsEvent'],
#  'dbpedia_6368': ['dbo:MusicalWork',
#   'dbo:Album',
#   'dbo:Film',
#   'dbo:Band',
#   'dbo:Single',
#   'dbo:Organisation',
#   'dbo:Person',
#   'dbo:Award',
#   'dbo:MusicGenre',
#   'dbo:Venue',
#   'dbo:Museum',
#   'dbo:Artist',
#   'dbo:MusicalArtist',
#   'dbo:TelevisionShow',
#   'dbo:Writer',
#   'dbo:ArtistDiscography',
#   'dbo:Musical',
#   'dbo:RecordLabel',
#   'dbo:Beverage',
#   'dbo:Song',
#   'dbo:BeautyQueen',
#   'dbo:BroadcastNetwork',
#   'dbo:Comedian',
#   'dbo:Company',
#   'dbo:FashionDesigner',
#   'dbo:Book',
#   'dbo:TelevisionSeason',
#   'dbo:Play',
#   'dbo:ScreenWriter',
#   'dbo:TelevisionEpisode'],
#  'dbpedia_14924': ['dbo:Play',
#   'dbo:Person',
#   'dbo:ReligiousBuilding',
#   'dbo:Royalty',
#   'dbo:OfficeHolder',
#   'dbo:IceHockeyPlayer',
#   'dbo:Writer',
#   'dbo:MilitaryPerson',
#   'dbo:Artist',
#   'dbo:Film',
#   'dbo:Curler',
#   'dbo:SoccerPlayer',
#   'dbo:Saint',
#   'dbo:Artwork',
#   'dbo:TennisPlayer',
#   'dbo:MartialArtist',
#   'dbo:Skier',
#   'dbo:Boxer',
#   'dbo:SoccerManager',
#   'dbo:Monument',
#   'dbo:FigureSkater',
#   'dbo:ChessPlayer',
#   'dbo:Gymnast',
#   'dbo:Book',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Athlete',
#   'dbo:Actor',
#   'dbo:Cyclist',
#   'dbo:Criminal'],
#  'dbpedia_14344': ['dbo:Place',
#   'dbo:Person',
#   'dbo:GovernmentAgency',
#   'dbo:City',
#   'dbo:Mountain',
#   'dbo:Planet',
#   'dbo:Constellation',
#   'dbo:VideoGame',
#   'dbo:RecordLabel',
#   'dbo:Mammal',
#   'dbo:FictionalCharacter',
#   'dbo:Venue',
#   'dbo:Disease',
#   'dbo:Software',
#   'dbo:Weapon',
#   'dbo:InformationAppliance',
#   'dbo:Royalty',
#   'dbo:Website',
#   'dbo:Scientist',
#   'dbo:Glacier',
#   'dbo:Park',
#   'dbo:BeachVolleyballPlayer',
#   'dbo:MilitaryStructure',
#   'dbo:MountainRange',
#   'dbo:Hospital',
#   'dbo:MusicalArtist',
#   'dbo:Company',
#   'dbo:Building',
#   'dbo:Album',
#   'dbo:Star'],
#  'dbpedia_18829': ['dbo:TelevisionShow',
#   'dbo:Award',
#   'dbo:Album',
#   'dbo:Play',
#   'dbo:Writer',
#   'dbo:Comic',
#   'dbo:VideoGame',
#   'dbo:RecordLabel',
#   'dbo:Film',
#   'dbo:Magazine',
#   'dbo:MusicalArtist',
#   'dbo:Artist',
#   'dbo:ComicsCreator',
#   'dbo:Musical',
#   'dbo:Book',
#   'dbo:Band',
#   'dbo:Comedian',
#   'dbo:Person',
#   'dbo:FictionalCharacter',
#   'dbo:TelevisionEpisode',
#   'dbo:Actor',
#   'dbo:ComicsCharacter',
#   'dbo:Song',
#   'dbo:Single',
#   'dbo:Journalist',
#   'dbo:Website',
#   'dbo:RadioProgram',
#   'dbo:Wrestler',
#   'dbo:TelevisionSeason',
#   'dbo:SoapCharacter'],
#  'dbpedia_18074': ['dbo:Person',
#   'dbo:River',
#   'dbo:SportsEvent',
#   'dbo:SportsTeam',
#   'dbo:Company',
#   'dbo:School',
#   'dbo:Museum',
#   'dbo:Book',
#   'dbo:Magazine',
#   'dbo:SportsLeague',
#   'dbo:Writer',
#   'dbo:SoccerClub',
#   'dbo:ChessPlayer',
#   'dbo:Software',
#   'dbo:OfficeHolder',
#   'dbo:ReligiousBuilding',
#   'dbo:MilitaryStructure',
#   'dbo:Film',
#   'dbo:Artist',
#   'dbo:Bank',
#   'dbo:Newspaper',
#   'dbo:Convention',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Food',
#   'dbo:BeautyQueen',
#   'dbo:Surname',
#   'dbo:Holiday',
#   'dbo:Organisation',
#   'dbo:Song'],
#  'dbpedia_21662': ['dbo:EthnicGroup',
#   'dbo:Organisation',
#   'dbo:School',
#   'dbo:University',
#   'dbo:Non-ProfitOrganisation',
#   'dbo:ReligiousBuilding',
#   'dbo:Building',
#   'dbo:OfficeHolder',
#   'dbo:Cleric',
#   'dbo:Politician',
#   'dbo:PoliticalParty',
#   'dbo:Magazine',
#   'dbo:Person',
#   'dbo:President',
#   'dbo:Artist',
#   'dbo:Monarch',
#   'dbo:Museum',
#   'dbo:Scientist',
#   'dbo:Religious',
#   'dbo:Writer',
#   'dbo:Philosopher',
#   'dbo:Newspaper',
#   'dbo:AcademicJournal',
#   'dbo:TelevisionStation',
#   'dbo:RadioStation',
#   'dbo:HistoricBuilding',
#   'dbo:BroadcastNetwork',
#   'dbo:HistoricPlace',
#   'dbo:Governor',
#   'dbo:Publisher'],
#  'dbpedia_8950': ['dbo:PoliticalParty',
#   'dbo:Person',
#   'dbo:Software',
#   'dbo:Politician',
#   'dbo:Company',
#   'dbo:Athlete',
#   'dbo:Boxer',
#   'dbo:Artist',
#   'dbo:Writer',
#   'dbo:Magazine',
#   'dbo:SoccerPlayer',
#   'dbo:BasketballPlayer',
#   'dbo:SoccerManager',
#   'dbo:PrimeMinister',
#   'dbo:Senator',
#   'dbo:VolleyballPlayer',
#   'dbo:MartialArtist',
#   'dbo:Venue',
#   'dbo:Film',
#   'dbo:MilitaryConflict',
#   'dbo:ChessPlayer',
#   'dbo:Museum',
#   'dbo:Food',
#   'dbo:Song',
#   'dbo:MusicalArtist',
#   'dbo:Diocese',
#   'dbo:Album',
#   'dbo:Cyclist',
#   'dbo:BaseballPlayer',
#   'dbo:Saint'],
#  'dbpedia_18': ['dbo:Person',
#   'dbo:Island',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:Software',
#   'dbo:Planet',
#   'dbo:AmericanFootballPlayer',
#   'dbo:City',
#   'dbo:School',
#   'dbo:Aircraft',
#   'dbo:Mountain',
#   'dbo:Scientist',
#   'dbo:PublicTransitSystem',
#   'dbo:Politician',
#   'dbo:Park',
#   'dbo:Newspaper',
#   'dbo:AdministrativeRegion',
#   'dbo:ProgrammingLanguage',
#   'dbo:Website',
#   'dbo:Company',
#   'dbo:Economist',
#   'dbo:Building',
#   'dbo:Bird',
#   'dbo:ArtificialSatellite',
#   'dbo:ShoppingMall',
#   'dbo:Book',
#   'dbo:Town',
#   'dbo:RaceHorse',
#   'dbo:OfficeHolder',
#   'dbo:HistoricPlace'],
#  'dbpedia_15649': ['dbo:Writer',
#   'dbo:University',
#   'dbo:Person',
#   'dbo:Artist',
#   'dbo:Politician',
#   'dbo:PoliticalParty',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:Architect',
#   'dbo:RacingDriver',
#   'dbo:Athlete',
#   'dbo:SoccerPlayer',
#   'dbo:Noble',
#   'dbo:SoccerManager',
#   'dbo:TennisPlayer',
#   'dbo:BadmintonPlayer',
#   'dbo:SoccerTournament',
#   'dbo:SoccerClubSeason',
#   'dbo:Restaurant',
#   'dbo:Skier',
#   'dbo:Single',
#   'dbo:Cyclist',
#   'dbo:HorseRider',
#   'dbo:Band',
#   'dbo:MilitaryConflict',
#   'dbo:HistoricBuilding',
#   'dbo:Swimmer',
#   'dbo:ChristianBishop',
#   'dbo:FootballMatch'],
#  'dbpedia_12912': ['dbo:Organisation',
#   'dbo:Non-ProfitOrganisation',
#   'dbo:Person',
#   'dbo:Settlement',
#   'dbo:Company',
#   'dbo:Country',
#   'dbo:EthnicGroup',
#   'dbo:PoliticalParty',
#   'dbo:Legislature',
#   'dbo:University',
#   'dbo:GovernmentAgency',
#   'dbo:Hospital',
#   'dbo:City',
#   'dbo:OfficeHolder',
#   'dbo:School',
#   'dbo:Holiday',
#   'dbo:Election',
#   'dbo:BusCompany',
#   'dbo:Airport',
#   'dbo:TradeUnion',
#   'dbo:Town',
#   'dbo:Bank',
#   'dbo:CricketTeam',
#   'dbo:TelevisionStation',
#   'dbo:Diocese',
#   'dbo:ProtectedArea',
#   'dbo:Park',
#   'dbo:PublicTransitSystem',
#   'dbo:Newspaper',
#   'dbo:President'],
#  'dbpedia_3538': ['dbo:Writer',
#   'dbo:Person',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Album',
#   'dbo:Athlete',
#   'dbo:Award',
#   'dbo:MusicalArtist',
#   'dbo:SoccerManager',
#   'dbo:Band',
#   'dbo:IceHockeyPlayer',
#   'dbo:Book',
#   'dbo:Film',
#   'dbo:ScreenWriter',
#   'dbo:GolfPlayer',
#   'dbo:BusinessPerson',
#   'dbo:Single',
#   'dbo:Play',
#   'dbo:FictionalCharacter',
#   'dbo:RecordLabel',
#   'dbo:Musical',
#   'dbo:OfficeHolder',
#   'dbo:Company',
#   'dbo:Reptile',
#   'dbo:GolfTournament',
#   'dbo:LawFirm',
#   'dbo:Software',
#   'dbo:NCAATeamSeason',
#   'dbo:BaseballPlayer',
#   'dbo:Building',
#   'dbo:RadioProgram'],
#  'dbpedia_12574': ['dbo:WrittenWork',
#   'dbo:Book',
#   'dbo:Person',
#   'dbo:Award',
#   'dbo:Writer',
#   'dbo:Organisation',
#   'dbo:Library',
#   'dbo:Play',
#   'dbo:Comic',
#   'dbo:Museum',
#   'dbo:ComicsCreator',
#   'dbo:Poem',
#   'dbo:Artist',
#   'dbo:Newspaper',
#   'dbo:Language',
#   'dbo:Cleric',
#   'dbo:Saint',
#   'dbo:FictionalCharacter',
#   'dbo:Scientist',
#   'dbo:Philosopher',
#   'dbo:Magazine',
#   'dbo:AcademicJournal',
#   'dbo:Royalty',
#   'dbo:Publisher',
#   'dbo:Journalist',
#   'dbo:Poet',
#   'dbo:Artwork',
#   'dbo:RadioProgram',
#   'dbo:Monarch',
#   'dbo:Website'],
#  'dbpedia_18556': ['dbo:River',
#   'dbo:BodyOfWater',
#   'dbo:Place',
#   'dbo:Lake',
#   'dbo:Sea',
#   'dbo:Plant',
#   'dbo:EthnicGroup',
#   'dbo:Island',
#   'dbo:Settlement',
#   'dbo:Mammal',
#   'dbo:Insect',
#   'dbo:Scientist',
#   'dbo:City',
#   'dbo:Bacteria',
#   'dbo:Glacier',
#   'dbo:MountainRange',
#   'dbo:Country',
#   'dbo:Mountain',
#   'dbo:MilitaryStructure',
#   'dbo:Animal',
#   'dbo:Species',
#   'dbo:Crustacean',
#   'dbo:Bird',
#   'dbo:Ship',
#   'dbo:Mollusca',
#   'dbo:AdministrativeRegion',
#   'dbo:ProtectedArea',
#   'dbo:Fish',
#   'dbo:Language',
#   'dbo:Park'],
#  'dbpedia_954': ['dbo:Country',
#   'dbo:Language',
#   'dbo:Company',
#   'dbo:MusicalArtist',
#   'dbo:OfficeHolder',
#   'dbo:Software',
#   'dbo:SoccerClub',
#   'dbo:Island',
#   'dbo:Planet',
#   'dbo:RecordLabel',
#   'dbo:Award',
#   'dbo:Castle',
#   'dbo:Museum',
#   'dbo:Person',
#   'dbo:Bridge',
#   'dbo:Book',
#   'dbo:Writer',
#   'dbo:AcademicJournal',
#   'dbo:Organisation',
#   'dbo:Holiday',
#   'dbo:Magazine',
#   'dbo:RadioStation',
#   'dbo:Newspaper',
#   'dbo:Convention',
#   'dbo:InformationAppliance',
#   'dbo:Scientist',
#   'dbo:Band',
#   'dbo:Painter',
#   'dbo:Film',
#   'dbo:Website'],
#  'dbpedia_18277': ['dbo:AmericanFootballPlayer',
#   'dbo:Person',
#   'dbo:GridironFootballPlayer',
#   'dbo:Venue',
#   'dbo:TelevisionShow',
#   'dbo:Single',
#   'dbo:Magazine',
#   'dbo:Book',
#   'dbo:Writer',
#   'dbo:Song',
#   'dbo:AustralianRulesFootballPlayer',
#   'dbo:RadioProgram',
#   'dbo:MemberOfParliament',
#   'dbo:Comedian',
#   'dbo:FictionalCharacter',
#   'dbo:Wrestler',
#   'dbo:OfficeHolder',
#   'dbo:Film',
#   'dbo:RugbyPlayer',
#   'dbo:MusicalArtist',
#   'dbo:Cricketer',
#   'dbo:Musical',
#   'dbo:TelevisionEpisode',
#   'dbo:Journalist',
#   'dbo:BaseballPlayer',
#   'dbo:NationalFootballLeagueSeason',
#   'dbo:ComicsCreator',
#   'dbo:Politician',
#   'dbo:Award',
#   'dbo:RadioStation'],
#  'dbpedia_8243': ['dbo:TelevisionShow',
#   'dbo:Drug',
#   'dbo:Person',
#   'dbo:Protein',
#   'dbo:Film',
#   'dbo:Band',
#   'dbo:Hospital',
#   'dbo:Organisation',
#   'dbo:ComicsCharacter',
#   'dbo:Non-ProfitOrganisation',
#   'dbo:Single',
#   'dbo:AmusementParkAttraction',
#   'dbo:Scientist',
#   'dbo:Lake',
#   'dbo:Model',
#   'dbo:Book',
#   'dbo:Award',
#   'dbo:TelevisionStation',
#   'dbo:Artist',
#   'dbo:TelevisionEpisode',
#   'dbo:Play',
#   'dbo:Album',
#   'dbo:MusicalArtist',
#   'dbo:TelevisionSeason',
#   'dbo:Painter',
#   'dbo:Writer',
#   'dbo:CultivatedVariety',
#   'dbo:Artwork',
#   'dbo:Star',
#   'dbo:Comedian'],
#  'dbpedia_20831': ['dbo:Country',
#   'dbo:Settlement',
#   'dbo:Island',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:Hotel',
#   'dbo:MilitaryPerson',
#   'dbo:Station',
#   'dbo:AdministrativeRegion',
#   'dbo:MountainRange',
#   'dbo:Bank',
#   'dbo:Organisation',
#   'dbo:SportsTeam',
#   'dbo:MilitaryUnit',
#   'dbo:Castle',
#   'dbo:Lighthouse',
#   'dbo:School',
#   'dbo:Airline',
#   'dbo:Film',
#   'dbo:Saint',
#   'dbo:Noble',
#   'dbo:Road',
#   'dbo:Ship',
#   'dbo:Magazine',
#   'dbo:Royalty',
#   'dbo:Town',
#   'dbo:Monarch',
#   'dbo:Cyclist',
#   'dbo:MilitaryStructure',
#   'dbo:MilitaryConflict'],
#  'dbpedia_18596': ['dbo:Person',
#   'dbo:GridironFootballPlayer',
#   'dbo:Award',
#   'dbo:Athlete',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Writer',
#   'dbo:Artist',
#   'dbo:Venue',
#   'dbo:Single',
#   'dbo:Band',
#   'dbo:RadioProgram',
#   'dbo:RugbyPlayer',
#   'dbo:SportsTeam',
#   'dbo:Stadium',
#   'dbo:RadioStation',
#   'dbo:BasketballPlayer',
#   'dbo:AmericanFootballTeam',
#   'dbo:NationalFootballLeagueSeason',
#   'dbo:NCAATeamSeason',
#   'dbo:CollegeCoach',
#   'dbo:OlympicEvent',
#   'dbo:SportsTeamMember',
#   'dbo:SoccerClubSeason',
#   'dbo:VideoGame',
#   'dbo:Newspaper',
#   'dbo:FootballLeagueSeason',
#   'dbo:AmericanFootballLeague',
#   'dbo:BusinessPerson',
#   'dbo:GolfTournament',
#   'dbo:SoccerTournament'],
#  ...}

# %%
with open("data/advanced_result.json", 'w') as f:
    json.dump(test_rankings, f)
print("advanced_result.json")
